# %% [markdown]
# # Stage 1: Data Cleaning & Preprocessing

# %% [markdown]
# ## 1. Importing Data & Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import unicodedata

pd.set_option("display.max_columns", None)

# %%
customers = pd.read_csv("Dataset - Original/olist_customers_dataset.csv")
locations = pd.read_csv("Dataset - Original/olist_geolocation_dataset.csv", low_memory=False)
order_items = pd.read_csv("Dataset - Original/olist_order_items_dataset.csv")
order_payments = pd.read_csv("Dataset - Original/olist_order_payments_dataset.csv")
order_reviews = pd.read_csv("Dataset - Original/olist_order_reviews_dataset.csv")
orders = pd.read_csv("Dataset - Original/olist_orders_dataset.csv")
products = pd.read_csv("Dataset - Original/olist_products_dataset.csv")
sellers = pd.read_csv("Dataset - Original/olist_sellers_dataset.csv")
category_translation = pd.read_csv("Dataset - Original/product_category_name_translation.csv")

# %% [markdown]
# ## 2. Handling Nulls, Duplicates & Data Inconsistencies

# %%
customers.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
locations.head(10)
# Out:
#    geolocation_zip_code_prefix   latitude  longitude geolocation_city  \
# 0                         1037 -23.545621 -46.639292        sao paulo
# 1                         1046 -23.546081 -46.644820        sao paulo
# 2                         1046 -23.546129 -46.642951        sao paulo
# 3                         1041 -23.544392 -46.639499        sao paulo
# 4                         1035 -23.541578 -46.641607        sao paulo
# 5                         1012 -23.547762 -46.635361        são paulo
# 6                         1047 -23.546273 -46.641225        sao paulo
# 7                         1013 -23.546923 -46.634264        sao paulo
# 8                         1029 -23.543769 -46.634278        sao paulo
# 9                         1011 -23.547640 -46.636032        sao paulo
#
#   geolocation_state  Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8
# 0                SP         NaN         NaN         NaN        NaN
# ...

# %%
locations.drop(columns=["Unnamed: 5", "Unnamed: 6", "Unnamed: 7", "Unnamed: 8"], axis=1, inplace=True)

# %%
locations.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# latitude                       0
# longitude                      0
# geolocation_city               0
# geolocation_state              1
# dtype: int64

# %%
locations.loc[locations["geolocation_state"].isna()]
# Out:
#         geolocation_zip_code_prefix  latitude  longitude geolocation_city  \
# 741901                        60360 -3.743053 -38.587256               fo
#
#        geolocation_state
# 741901               NaN

# %%
locations.loc[locations["geolocation_city"] == 'fo']
# Out:
#         geolocation_zip_code_prefix  latitude  longitude geolocation_city  \
# 741901                        60360 -3.743053 -38.587256               fo
#
#        geolocation_state
# 741901               NaN

# %%
locations = locations[locations["geolocation_city"] != "fo"]
locations.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# latitude                       0
# longitude                      0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print(locations["geolocation_city"].unique())
# Out:
# ['sao paulo' 'são paulo' 'sao bernardo do campo' ... 'francisco dantas'
#  'parana' 'fortaleza']

# %%
def remove_accents(text):
    if isinstance(text, str):
        return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8').lower().strip()
    return text

locations['geolocation_city'] = locations['geolocation_city'].apply(remove_accents)

locations.head(10)
# Out:
#    geolocation_zip_code_prefix   latitude  longitude geolocation_city  \
# 0                         1037 -23.545621 -46.639292        sao paulo
# 1                         1046 -23.546081 -46.644820        sao paulo
# 2                         1046 -23.546129 -46.642951        sao paulo
# 3                         1041 -23.544392 -46.639499        sao paulo
# 4                         1035 -23.541578 -46.641607        sao paulo
# 5                         1012 -23.547762 -46.635361        sao paulo
# 6                         1047 -23.546273 -46.641225        sao paulo
# 7                         1013 -23.546923 -46.634264        sao paulo
# 8                         1029 -23.543769 -46.634278        sao paulo
# 9                         1011 -23.547640 -46.636032        sao paulo
#
#   geolocation_state
# 0                SP
# 1                SP
# 2                SP
# 3                SP
# 4                SP
# 5                SP
# 6                SP
# 7                SP
# ...

# %%
locations.duplicated().sum()
# Out:
# np.int64(219528)

# %%
locations.drop_duplicates(inplace=True)

# %%
order_items.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.head(10)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_payments.head(10)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5  298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6  771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7  3d7239c394a212faae122962df514ac7                   1  credit_card
# 8  1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9  0573b5e23cbd798006520e1d5b4c6714                   1       boleto
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# ...

# %%
order_payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_payments["payment_type"].unique()
# Out:
# array(['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined'],
#       dtype=object)

# %%
order_payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
order_payments[order_payments["payment_type"] == "not_defined"]
# Out:
#                                order_id  payment_sequential payment_type  \
# 51280  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411  00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 94427  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
#
#        payment_installments  payment_value
# 51280                     1            0.0
# 57411                     1            0.0
# 94427                     1            0.0

# %%
order_payments = order_payments[order_payments["payment_type"] != "not_defined"]

order_payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# Name: count, dtype: int64

# %%
order_payments.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_reviews.head(10)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5  15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6  07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7  7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
# 8  a3f6f7f6f433de0aefbb97da197c554c  9c214ac970e84273583ab523dfafd09b
# 9  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# ...

# %%
order_reviews["review_score"].unique()
# Out:
# array([4, 5, 1, 3, 2])

# %%
order_reviews.isna().sum() / len(order_reviews) * 100
# Out:
# review_id                   0.000000
# order_id                    0.000000
# review_score                0.000000
# review_comment_title       88.341530
# review_comment_message     58.702532
# review_creation_date        0.000000
# review_answer_timestamp     0.000000
# dtype: float64

# %%
order_reviews.drop(columns=["review_comment_title", "review_comment_message"], axis=1, inplace=True)
order_reviews.isna().sum() / len(order_reviews) * 100
# Out:
# review_id                  0.0
# order_id                   0.0
# review_score               0.0
# review_creation_date       0.0
# review_answer_timestamp    0.0
# dtype: float64

# %%
order_reviews["review_creation_date"] = pd.to_datetime(order_reviews["review_creation_date"]).dt.date
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp
# 0             4           2018-01-18     2018-01-18 21:46:59
# 1             5           2018-03-10     2018-03-11 03:05:13
# 2             5           2018-02-17     2018-02-18 14:36:24
# 3             5           2017-04-21     2017-04-21 22:02:06
# 4             5           2018-03-01     2018-03-02 10:26:53

# %%
order_reviews.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %%
orders["order_status"].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'unavailable',
#        'canceled', 'created', 'approved'], dtype=object)

# %%
len(orders)
# Out:
# 99441

# %%
orders.isna().sum() / len(orders) * 100
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.160899
# order_delivered_carrier_date     1.793023
# order_delivered_customer_date    2.981668
# order_estimated_delivery_date    0.000000
# dtype: float64

# %%
orders.dropna(inplace=True)

len(orders)
# Out:
# 96461

# %%
orders["order_estimated_delivery_date"] = pd.to_datetime(orders["order_estimated_delivery_date"]).dt.date

orders.head(10)
# Out:
#                             order_id                       customer_id  \
# 0   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2   47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3   949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4   ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5   a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 7   6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8   76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9   e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
# 10  e6ce16cb79ec1d90b1da9085a6118aeb  494dded5b201313c64ed7f100595b95c
#
#    order_status order_purchase_timestamp    order_approved_at  \
# 0     delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# ...

# %%
products.head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# ...

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
import missingno as msno

msno.matrix(products)
plt.show()

# %%
products.dropna(subset=["product_category_name", "product_name_lenght", "product_description_lenght"], inplace=True)

products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              1
# product_length_cm             1
# product_height_cm             1
# product_width_cm              1
# dtype: int64

# %%
products.loc[products["product_weight_g"].isna()]
# Out:
#                             product_id product_category_name  \
# 8578  09ff539a621711667c43eba6a3bd8466                 bebes
#
#       product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                 60.0                       865.0                 3.0
#
#       product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 8578               NaN                NaN                NaN               NaN

# %%
products.loc[products["product_category_name"] == "bebes"]
# Out:
#                              product_id product_category_name  \
# 3      cef67bcfe19066a932b7673e239eb23d                 bebes
# 11     03b63c5fc16691530586ae020c345514                 bebes
# 23     8b41fbc2b984a12030090112324d1bc4                 bebes
# 35     5370b82a213393979691c98074265584                 bebes
# 43     b864b103180d5a6a3f830e67f93e8735                 bebes
# ...                                 ...                   ...
# 32823  cba32576375902a87170bedaed045b71                 bebes
# 32851  026311ea0b72ef8c80ebf91efd36b499                 bebes
# 32853  34c84b2e246f5904a5b3597b00240ea2                 bebes
# 32935  d4484cc239fbd0ac671ab04d931edc66                 bebes
# 32941  6ec96c91757fad0aecafc0ee7f262dcc                 bebes
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 3                     27.0                       261.0                 1.0
# ...

# %%
cols = ["product_weight_g", "product_length_cm", "product_height_cm", "product_width_cm"]
bebes_mean = products.loc[products["product_category_name"] == "bebes", cols].mean()

products.loc[products["product_category_name"] == "bebes", cols] = \
products.loc[products["product_category_name"] == "bebes", cols].fillna(bebes_mean)

products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
sellers.head(10)
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5  c240c4061717ac1806ae6ee72be3533b                   20920
# 6  e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7  1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8  768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9  ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# 5     rio de janeiro           RJ
# 6             brejao           PE
# ...

# %%
sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sellers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.to_csv("customers.csv", index=False)
locations.to_csv("locations.csv", index=False)
order_items.to_csv("order_items.csv", index=False)
order_payments.to_csv("order_payments.csv", index=False)
order_reviews.to_csv("order_reviews.csv", index=False)
orders.to_csv("orders.csv", index=False)
products.to_csv("products.csv", index=False)
sellers.to_csv("sellers.csv", index=False)
